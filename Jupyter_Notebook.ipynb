# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. sql
# 4. Java
# 5. Scala
#
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. NumPy
# 2. Pandas
# 3. TensorFlow
# 4. Pytorch

# %% [markdown]
# Data Science Tools
#
# | item | tool            |
# | ---- | --------------- |
# | 1    | Jupyternotebook |
# | 2    | rstudio         |
# | 3    | github          |

# %% [markdown]
# Below are a few examples of evaluating arithmetic expressions in Python.

# %%
(3*4)+5 #This a simple arithmetic expression to mutiply then add integers.
# Out:
# 17

# %%
1+2
2*4
# Out:
# 8

# %%
def min_to_hour(x):
    hour = x / 60
    print(f'{x} minutes is {hour:.2f} hours')
min_to_hour(200)
# Out:
# 200 minutes is 3.33 hours

# %% [markdown]
# ### **Objectives:**
#
# - List popular languages for Data Science (e.g., Python, R, SQL)
# - Identify common open-source development environments and tools
# - Demonstrate creating Markdown and code cells in a Jupyter notebook
# - Perform simple unit conversions and basic calculations in code cells
# - Summarize key takeaways and next learning steps

# %% [markdown]
# ## Author
# Cindy Shi
